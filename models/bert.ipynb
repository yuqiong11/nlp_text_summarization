# %%
# !pip install bert-extractive-summarizer
# !pip install spacy==2.1.3

# %%
# from dataframe
test_text = test['text']
test_summary = test['summary']

# %%
from summarizer import Summarizer
model = Summarizer()

with open('gen_summary_bert.csv', 'w', newline='') as csvfile:
    fieldnames = ['gen_summary']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()

    # loop over all test samples, generate summaries and write them into rows in csv file
    for i in range(len(test_text)):
      result = model(test_text.iloc[i], num_sentences=4)
      full = ''.join(result)
      writer.writerow({'gen_summary':full})
